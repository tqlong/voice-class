# %%
import librosa
# Out:
# D:\software\conda\envs\voice\lib\site-packages\sklearn\utils\__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Sequence
# D:\software\conda\envs\voice\lib\site-packages\sklearn\model_selection\_split.py:18: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# D:\software\conda\envs\voice\lib\site-packages\sklearn\model_selection\_search.py:16: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, namedtuple, defaultdict, Sequence

# %%
y, sr = librosa.load('voicebook/chapter_1_fundamentals/data/one.wav')

# %%
sr
# Out:
# 22050

# %%
len(y) / sr
# Out:
# 2.9440362811791383

# %%
librosa.output.write_wav('new_test.wav', y, sr)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y
# Out:
# array([ 6.4160777e-12,  1.3676048e-11, -3.3840507e-11, ...,
#         4.4742560e-06, -9.0348061e-05,  0.0000000e+00], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(y)

# %%
import numpy as np
x = np.arange(len(y)) / sr
plt.plot(x, y)

# %%
tmin, tmax = 0.450, 0.475
imin, imax = int(tmin*sr), int(tmax*sr)
plt.plot(x[imin:imax], y[imin:imax])
